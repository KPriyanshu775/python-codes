# %%
import cv2
print("The version of the OpenCv is: ",cv2.__version__)
# Out:
# The version of the OpenCv is:  5.0.0

# %%
image = cv2.imread("pk.jpg")

# %%
image
# Out:
# array([[[224, 213, 199],
#         [224, 213, 199],
#         [224, 213, 199],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[224, 213, 199],
#         [224, 213, 199],
#         [224, 213, 199],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[224, 213, 199],
#         [224, 213, 199],
#         [224, 213, 199],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[117, 166, 176],
#         [116, 166, 178],
#         [104, 156, 172],
#         ...,
#         [ 69, 139, 162],
#         [ 71, 139, 162],
#         [ 57, 125, 148]],
#
#        [[121, 165, 172],
#         [118, 164, 172],
#         [115, 162, 176],
#         ...,
#         [ 84, 154, 177],
#         [ 99, 167, 190],
#         [ 70, 138, 161]],
#
#        [[125, 165, 170],
#         [121, 163, 170],
#         [126, 171, 185],
# ...

# %%
print(type(image))
print(image.shape)
# Out:
# <class 'numpy.ndarray'>
# (1488, 1116, 3)

# %%
cv2.imshow("Original Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
